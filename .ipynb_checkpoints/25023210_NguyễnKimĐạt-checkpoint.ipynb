# %% [markdown]
# W4A1

# %%
def nhap():
    n = int(input("Nhập một số n (n <= 1000): "))
    while n > 1000:
        print("Vui lòng nhập số nhỏ hơn hoặc bằng 1000")
        n = int(input("Nhập lại n: "))
    return n

n = nhap()

ans = 0
for i in range(1, n + 1):
    ans += i

print(f"Tổng các số hạng từ 1 đến n là: {ans}")
# Out:
# Nhập một số n (n <= 1000):  10000
# Vui lòng nhập số nhỏ hơn hoặc bằng 1000
# Nhập lại n:  100
# Tổng các số hạng từ 1 đến n là: 5050

# %% [markdown]
# W4A2

# %%
def nguyenduong():
    n = int(input("Nhập 1 số nguyên dương: "))
    while n <= 0:
        print("Vui lòng nhập số dương")
        n = int(input("Nhập số n: "))
    return n
n = nguyenduong()
if n == 1:
    print("1 không phải số nguyên tố")
else:
    for i in range(2, int(n**(1/2))):
        if n % i == 0:
            print(f"{n} không phải số nguyên tố")
            break
    else:
        print(f"{n} là số nguyên tố")
# Out:
# Nhập 1 số nguyên dương:  11
# 11 là số nguyên tố

# %% [markdown]
# W4A3

# %%
def giaithua():
    n = int(input("Nhập 1 số n: "))
    while not 0 < n < 100:
        print("Vui lòng nhập lại số n!")
        n = int(input("Nhập số n: "))
    return n
n = giaithua()
ans = 1
for i in range(2, n + 1):
    ans *= i
print(f"n! = {ans}" )
# Out:
# Nhập 1 số n:  100
# Vui lòng nhập lại số n!
# Nhập số n:  99
# n! = 933262154439441526816992388562667004907159682643816214685929638952175999932299156089414639761565182862536979208272237582511852109168640000000000000000000000

# %% [markdown]
# W4A4

# %%
n = int(input("Nhập 1 số n: "))
